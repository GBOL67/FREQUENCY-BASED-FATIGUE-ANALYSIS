# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# OMOGBOLAHAN ADEDAMOLA OLADIPUPO
# MODELLING AND SIMULATION ENGINEER

# %% [markdown]
# *I am interested in data science because it involves the processing of data to solve problems which works in all fields.*

# %% [markdown]
# ## The Code Below Perfoms The Addition Of Two Integers

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# 1. Numbered item
# - bullet point
# |Name | Country|
# |-----|--------|
# |Charles|England|
# |John| USA|
# |Rafael|Portugal|
